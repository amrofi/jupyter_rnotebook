# %% [markdown]
# <a href="https://colab.research.google.com/github/amrofi/jupyter_rnotebook/blob/master/varejoms%2Bcom%2Bforecast%2BTheta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
varejoms <- structure(c(35.2, 35.6, 39.2, 40.5, 41.6, 40.4, 40.8, 38.7, 37.3, 
    37.6, 35.6, 47.4, 34.2, 32.2, 38, 37.5, 38.8, 35, 38.4, 40.2, 38.2, 39.3, 
    36, 46.3, 36.4, 34, 39, 37.8, 38.9, 35.3, 37.2, 38.1, 35.6, 38.3, 35.6, 
    45.7, 32.2, 31.6, 35.2, 36.8, 37.5, 34.8, 38.4, 38.1, 37, 39, 37.3, 49, 
    35.8, 35.3, 40.2, 41.3, 43.9, 41.6, 45.9, 42.3, 42.2, 44, 41.3, 56.9, 38.5, 
    38.5, 45.3, 43.6, 46.2, 44.3, 47.5, 46.5, 46.4, 46, 44.1, 61, 42, 40.2, 
    44.6, 44.5, 47.8, 45.3, 46.5, 48.5, 47.7, 50.2, 49.3, 64.5, 47, 46.8, 51, 
    50.5, 55, 51.3, 52.8, 55.3, 54.8, 55.6, 55.3, 72.2, 54.5, 52.1, 56.2, 57.2, 
    60.8, 56.1, 61.8, 61.6, 59.8, 63.3, 57.7, 77.4, 61.4, 51.9, 57.3, 57.9, 
    61.9, 57.3, 61.1, 61.1, 60.6, 65.6, 63.5, 83.1, 64.1, 60.2, 67.8, 67.1, 
    72.8, 68.5, 71.1, 69.3, 69.9, 71.1, 67.9, 92.7, 67.5, 64.8, 69.1, 69.4, 
    79.6, 70.2, 73.8, 72.5, 71.3, 75.6, 74.7, 100.8, 79.5, 75.7, 82.4, 78, 84.8, 
    83.2, 84.8, 88.5, 86.3, 91.7, 92.8, 111.4, 92.8, 83.7, 92.5, 88.3, 93.9, 
    88.8, 96, 95.9, 93.2, 98.3, 100.5, 128.8, 97.2, 90.2, 94.3, 94.4, 101.1, 
    92, 96.4, 98.2, 97.6, 105.8, 103.1, 129.6, 99.6, 87.8, 97, 94.8, 98.6, 93.4, 
    98.4, 96.4, 92.5, 100.6, 97.2, 124.5, 91.5, 85.1, 91.6, 88.5, 92.2, 87.4, 
    90.5, 88.1, 85.2, 89.4, 93.4, 116.9, 90.8, 84, 89.7, 86.3, 90, 87.3, 90.8, 
    93.5, 93.7, 91.4, 93.5, 114.1, 87.8, 81.1, 94.5, 83.2, 89.9, 88.8, 89.3, 
    93.7, 93.5, 96.3, 101.3, 118.3, 93.8, 85.2, 90, 86.6, 90, 85.2, 91, 94.1), 
    .Tsp = c(2000, 2019.58333333333, 12), class = "ts")
print(varejoms)
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 2000  35.2  35.6  39.2  40.5  41.6  40.4  40.8  38.7  37.3  37.6  35.6  47.4
# 2001  34.2  32.2  38.0  37.5  38.8  35.0  38.4  40.2  38.2  39.3  36.0  46.3
# 2002  36.4  34.0  39.0  37.8  38.9  35.3  37.2  38.1  35.6  38.3  35.6  45.7
# 2003  32.2  31.6  35.2  36.8  37.5  34.8  38.4  38.1  37.0  39.0  37.3  49.0
# 2004  35.8  35.3  40.2  41.3  43.9  41.6  45.9  42.3  42.2  44.0  41.3  56.9
# 2005  38.5  38.5  45.3  43.6  46.2  44.3  47.5  46.5  46.4  46.0  44.1  61.0
# 2006  42.0  40.2  44.6  44.5  47.8  45.3  46.5  48.5  47.7  50.2  49.3  64.5
# 2007  47.0  46.8  51.0  50.5  55.0  51.3  52.8  55.3  54.8  55.6  55.3  72.2
# 2008  54.5  52.1  56.2  57.2  60.8  56.1  61.8  61.6  59.8  63.3  57.7  77.4
# 2009  61.4  51.9  57.3  57.9  61.9  57.3  61.1  61.1  60.6  65.6  63.5  83.1
# 2010  64.1  60.2  67.8  67.1  72.8  68.5  71.1  69.3  69.9  71.1  67.9  92.7
# 2011  67.5  64.8  69.1  69.4  79.6  70.2  73.8  72.5  71.3  75.6  74.7 100.8
# 2012  79.5  75.7  82.4  78.0  84.8  83.2  84.8  88.5  86.3  91.7  92.8 111.4
# 2013  92.8  83.7  92.5  88.3  93.9  88.8  96.0  95.9  93.2  98.3 100.5 128.8
# 2014  97.2  90.2  94.3  94.4 101.1  92.0  96.4  98.2  97.6 105.8 103.1 129.6
# 2015  99.6  87.8  97.0  94.8  98.6  93.4  98.4  96.4  92.5 100.6  97.2 124.5
# 2016  91.5  85.1  91.6  88.5  92.2  87.4  90.5  88.1  85.2  89.4  93.4 116.9
# 2017  90.8  84.0  89.7  86.3  90.0  87.3  90.8  93.5  93.7  91.4  93.5 114.1
# 2018  87.8  81.1  94.5  83.2  89.9  88.8  89.3  93.7  93.5  96.3 101.3 118.3
# 2019  93.8  85.2  90.0  86.6  90.0  85.2  91.0  94.1

# %%
class(varejoms)
# Out:
# [1] "ts"

# %%
dvarejo <- diff(varejoms)
# estatisticas basicas
summary(varejoms)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   31.60   44.08   64.65   67.39   90.05  129.60

# %%
# plot basico
plot(varejoms)
# Out:
# plot without title

# %%
install.packages('forecast', repos='http://cran.rstudio.com/')
forecast::ggtsdisplay(varejoms,main = "Série de Varejo MS")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’
#
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# plot without title

# %%
 install.packages(c('dplyr','magrittr'), repos='http://cran.rstudio.com/')
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
 library(magrittr);library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
varejo %>% diff() %>% forecast::ggtsdisplay(main = "Série varejo de MS em primeira diferença")
# Out:
# plot without title

# %%
varejo %>% diff(lag = 12) %>% forecast::ggtsdisplay(main = "Série varejo de MS em primeira diferença sazonal")
# Out:
# plot without title

# %%
 install.packages(c('fpp2','forecTheta'), repos='http://cran.rstudio.com/')
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(fpp2)
# Out:
# Loading required package: ggplot2
#
# Loading required package: forecast
#
# Loading required package: fma
#
# Loading required package: expsmooth

# %%
varejoadj <- varejo %>% stl(s.window = "periodic") %>% seasadj()
plot(varejoadj, main = "Série de Varejo MS com ajuste sazonal STL")
# Out:
# Plot with title “Série de Varejo MS com ajuste sazonal STL”

# %%
varejoadj %>% diff() %>% forecast::ggtsdisplay(main = "Série varejo de MS em primeira diferença e ajuste sazonal")
# Out:
# plot without title

# %%
y <- varejoms
h = 12
require(forecast)
T <- thetaf(y, h)$mean
plot(thetaf(y, h))
# Out:
# Plot with title “Forecasts from Theta”

# %%
modelo <- thetaf(y, h)
summary(modelo)
# Out:
# Forecast method: Theta
#
# Model Information:
# $alpha
# [1] 0.6379929
#
# $drift
#         X
# 0.1636578
#
# $sigma
# [1] 5.651715
#
# $call
# thetaf(y = y, h = h)
#
#
# Error measures:
#                     ME     RMSE      MAE       MPE     MAPE      MASE
# Training set 0.3545975 2.389965 1.818344 0.5126286 2.748774 0.3983852
#                     ACF1
# Training set -0.09309372
#
# Forecasts:
#          Point Forecast     Lo 80     Hi 80     Lo 95     Hi 95
# Sep 2019       90.76717  87.72049  93.81384  86.10768  95.42666
# Oct 2019       94.53450  90.92057  98.14842  89.00748 100.06151
# Nov 2019       92.07228  87.96879  96.17577  85.79654  98.34802
# Dec 2019      118.91229 114.37172 123.45287 111.96808 125.85650
# Jan 2020       89.33067  84.39154  94.26980  81.77692  96.88442
# Feb 2020       83.61381  78.30597  88.92165  75.49616  91.73146
# Mar 2020       92.45136  86.79880  98.10392  83.80652 101.09620
# Apr 2020       90.56873  84.59130  96.54615  81.42705  99.71041
# May 2020       96.09921  89.81369 102.38473  86.48634 105.71209
# Jun 2020       89.79625  83.21704  96.37546  79.73422  99.85828
# Jul 2020       94.82093  87.96059 101.68126  84.32895 105.31290
# Aug 2020       94.79960  87.66922 101.92999  83.89462 105.70458

# %%
(modelo)
# Out:
#          Point Forecast     Lo 80     Hi 80     Lo 95     Hi 95
# Sep 2019       90.76717  87.72049  93.81384  86.10768  95.42666
# Oct 2019       94.53450  90.92057  98.14842  89.00748 100.06151
# Nov 2019       92.07228  87.96879  96.17577  85.79654  98.34802
# Dec 2019      118.91229 114.37172 123.45287 111.96808 125.85650
# Jan 2020       89.33067  84.39154  94.26980  81.77692  96.88442
# Feb 2020       83.61381  78.30597  88.92165  75.49616  91.73146
# Mar 2020       92.45136  86.79880  98.10392  83.80652 101.09620
# Apr 2020       90.56873  84.59130  96.54615  81.42705  99.71041
# May 2020       96.09921  89.81369 102.38473  86.48634 105.71209
# Jun 2020       89.79625  83.21704  96.37546  79.73422  99.85828
# Jul 2020       94.82093  87.96059 101.68126  84.32895 105.31290
# Aug 2020       94.79960  87.66922 101.92999  83.89462 105.70458

# %%
library(forecTheta)
# Out:
# Loading required package: parallel
#
# Loading required package: tseries

# %%
y <- varejoms
h = 12
set.seed(12345)
mod2 <- dotm(y, h)
plot(mod2)
# Out:
# Plot with title “Dynamic Optimised Theta Model”

# %%
(mod2)
# Out:
# Forecast method: Dynamic Optimised Theta Model
#
# Seasonal decomposition type: multiplicative
#
# Optimisation method: Nelder-Mead
#
# Number of theta lines: 2
#
# Weights for theta lines:
#         Estimative
# omega_1       0.48
# omega_2       0.52
#
# Estimative of parameters:
#         MLE
# ell0  15.61
# alpha  0.62
# theta  1.92
#
# Forecasting points and prediction intervals
#              Mean    Lo 80    Hi 80    Lo 90    Hi 90    Lo 95    Hi 95
# Sep 2019  90.7055  87.7358  94.3555  87.0361  95.0432  86.5322  95.7098
# Oct 2019  94.4625  91.2530  98.5915  90.4380  99.4901  89.5612 100.3729
# Nov 2019  91.9939  87.9531  96.3013  87.0091  97.6981  86.1153  98.2929
# Dec 2019 118.7997 113.5964 125.0013 112.1571 126.6257 111.3828 127.9087
# Jan 2020  89.2369  84.7963  94.2359  83.4705  95.0678  82.5591  96.2033
# Feb 2020  83.5169  78.5097  88.5590  77.4747  89.7529  76.9382  91.4349
# Mar 2020  92.3336  86.7244  98.2125  85.8621  99.3112  83.9983 100.0960
# Apr 2020  90.4424  85.1185  96.1328  83.1143  97.9635  82.2356  98.6804
# May 2020  95.9529  89.7126 102.5335  88.8577 103.9769  85.8770 104.7699
# Jun 2020  89.6476  83.1236  96.1505  81.8708  97.2885  80.7374  98.5336
# Jul 2020  94.6507  87.0673 101.6476  85.5549 103.3302  84.9208 104.3466
# Aug 2020  94.6157  86.7363 101.6285  85.6061 103.3821  85.0348 104.6449
#
# Warning: According with the Shapiro-Wilk test with 97% of confidence, the unseasoned residuals do not follow the Normal distribution. The prediction intervals may not be adequate.

# %%
# Parâmetro theta estimado:
 
mod2$par[2]  # alpha
# [1] 0.6234402
# Out:
# [1] 0.6234402

# %%
mod2$par[3]  # theta
#[1] 1.921107
# Out:
# [1] 1.921107

# %%
#Pesos estimados:
 
mod2$weights
# Out:
#         Estimative
# omega_1 0.4794667
# omega_2 0.5205333

# %% [markdown]
# Valores iniciais dos thetas: 0,5 e 2. Opções para Método de otimização: ‘Nelder-Mead’, ‘L-BFGS-B’, ‘SANN’. O padrão é ‘Nelder-Mead’.

# %%
mod2$opt.method
#[1] "Nelder-Mead"
# Out:
# [1] "Nelder-Mead"

# %% [markdown]
# # Comparação com dados recentes

# %%
# dadosnovos<-BETS::BETSget(1479)
dadosnovos <- structure(c(35.2, 35.6, 39.2, 40.5, 41.6, 40.4, 40.8, 38.7, 37.3, 37.6, 
    35.6, 47.4, 34.2, 32.2, 38, 37.5, 38.8, 35, 38.4, 40.2, 38.2, 39.3, 36, 46.3, 
    36.4, 34, 39, 37.8, 38.9, 35.3, 37.2, 38.1, 35.6, 38.3, 35.6, 45.7, 32.2, 31.6, 
    35.2, 36.8, 37.5, 34.8, 38.4, 38.1, 37, 39, 37.3, 49, 35.8, 35.3, 40.2, 41.3, 
    43.9, 41.6, 45.9, 42.3, 42.2, 44, 41.3, 56.9, 38.5, 38.5, 45.3, 43.6, 46.2, 44.3, 
    47.5, 46.5, 46.4, 46, 44.1, 61, 42, 40.2, 44.6, 44.5, 47.8, 45.3, 46.5, 48.5, 
    47.7, 50.2, 49.3, 64.5, 47, 46.8, 51, 50.5, 55, 51.3, 52.8, 55.3, 54.8, 55.6, 
    55.3, 72.2, 54.5, 52.1, 56.2, 57.2, 60.8, 56.1, 61.8, 61.6, 59.8, 63.3, 57.7, 
    77.4, 61.4, 51.9, 57.3, 57.9, 61.9, 57.3, 61.1, 61.1, 60.6, 65.6, 63.5, 83.1, 
    64.1, 60.2, 67.8, 67.1, 72.8, 68.5, 71.1, 69.3, 69.9, 71.1, 67.9, 92.7, 67.5, 
    64.8, 69.1, 69.4, 79.6, 70.2, 73.8, 72.5, 71.3, 75.6, 74.7, 100.8, 79.5, 75.7, 
    82.4, 78, 84.8, 83.2, 84.8, 88.5, 86.3, 91.7, 92.8, 111.4, 92.8, 83.7, 92.5, 
    88.3, 93.9, 88.8, 96, 95.9, 93.2, 98.3, 100.5, 128.8, 97.2, 90.2, 94.3, 94.4, 
    101.1, 92, 96.4, 98.2, 97.6, 105.8, 103.1, 129.6, 99.6, 87.8, 97, 94.8, 98.6, 
    93.4, 98.4, 96.4, 92.5, 100.6, 97.2, 124.5, 91.5, 85.1, 91.6, 88.5, 92.2, 87.4, 
    90.5, 88.1, 85.2, 89.4, 93.4, 116.9, 90.8, 84, 89.7, 86.3, 90, 87.3, 90.8, 93.5, 
    93.7, 91.4, 93.5, 114.1, 87.8, 81.1, 94.5, 83.2, 89.9, 88.8, 89.3, 93.7, 93.5, 
    96.3, 101.3, 118.3, 93.8, 85.2, 90, 86.6, 90, 85.2, 91, 94.4, 93.4, 95.9, 102.6, 
    116, 94.9, 89.1), .Tsp = c(2000, 2020.08333333333, 12), class = "ts")
# View(cbind.zoo(data.fcst,dadosnovos))
require(zoo)
print(cbind.zoo(T, dadosnovos)[230:242])
# Out:
#                  T dadosnovos
# Feb 2019        NA       85.2
# Mar 2019        NA       90.0
# Apr 2019        NA       86.6
# May 2019        NA       90.0
# Jun 2019        NA       85.2
# Jul 2019        NA       91.0
# Aug 2019        NA       94.4
# Sep 2019  90.76717       93.4
# Oct 2019  94.53450       95.9
# Nov 2019  92.07228      102.6
# Dec 2019 118.91229      116.0
# Jan 2020  89.33067       94.9
# Feb 2020  83.61381       89.1

# %% [markdown]
# ## Acurácia do período Setembro/2019 a fev/2020:

# %%
# pelo forecast::thetaf T <- thetaf(y, h)$mean
previsto <- T
observado <- dadosnovos[237:242]
forecast::accuracy(previsto, observado)
# Out:
#          ME       RMSE     MAE      MPE      MAPE
# Test set 3.777527 5.615429 4.748577 4.002483 4.839596

# %% [markdown]
# Ou seja, um erro percentual médio de 4.00% e um erro absoluto médio de ≈4.75%.

# %% [markdown]
# ## Comparação com o forecTheta::dotm

# %%
# pelo forecTheta::dotm 
T2<- dotm(y,h)$mean
previsto2 <- T2
observado <- dadosnovos[237:242]
forecast::accuracy(previsto2, observado)
# Out:
#          ME       RMSE     MAE      MPE      MAPE
# Test set 3.864104 5.670028 4.797325 4.090202 4.894704

# %% [markdown]
# Ou seja, um erro percentual médio de 4.09% e um erro absoluto médio de ≈4.80%.

# %%
# fim
